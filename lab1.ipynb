# %%
import pandas as pd

covid=pd.read_csv("s3://ia-340-2025-fall-1551/data.csv")

covid.head()
# Out:
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/pandas/core/computation/expressions.py:21: UserWarning: Pandas requires version '2.8.4' or newer of 'numexpr' (version '2.7.3' currently installed).
#   from pandas.core.computation.check import NUMEXPR_INSTALLED
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/fsspec/registry.py:298: UserWarning: Your installed version of s3fs is very old and known to cause
# severe performance issues, see also https://github.com/dask/dask/issues/10276
#
# To fix, you should specify a lower version bound on s3fs, or
# update the current installation.
#
#   warnings.warn(s3_msg)
#       dateRep  day  month  year  cases  deaths countriesAndTerritories geoId  \
# 0  14/12/2020   14     12  2020    746       6             Afghanistan    AF
# 1  13/12/2020   13     12  2020    298       9             Afghanistan    AF
# 2  12/12/2020   12     12  2020    113      11             Afghanistan    AF
# ...

# %%
pol=pd.read_csv("s3://ia-340-2025-fall-1551/Chesapeake_Bay_Pollution_Loads_-_Nitrogen.csv")

pol.head()
# Out:
#     Land-River Segment   FIPS    County Tributary Basin          Major Basin  \
# 0  A24001PU0_3871_3690  24001  ALLEGANY   Upper Potomac  Potomac River Basin
# 1  A24001PU0_3871_3690  24001  ALLEGANY   Upper Potomac  Potomac River Basin
# 2  A24001PU0_3871_3690  24001  ALLEGANY   Upper Potomac  Potomac River Basin
# 3  A24001PU0_3871_3690  24001  ALLEGANY   Upper Potomac  Potomac River Basin
# 4  A24001PU0_3871_3690  24001  ALLEGANY   Upper Potomac  Potomac River Basin
#
#    Source Sector  Total N, 1985 (lb.)  Total N, 2007 (lb.)  \
# 0         Forest         51155.919439         44291.188482
# 1  Non-Tidal Atm            23.744801            11.600470
# 2         Septic           593.984192           539.573425
# 3     Stormwater          4163.487261          2510.113876
# 4     Wastewater           153.179901            54.931515
#
#    Total N, 2009 (lb.)  Total N, 2010 (lb.)  Total N, 2011 (lb.)  \
# 0         44013.497319         44071.130371         44127.954834
# ...
